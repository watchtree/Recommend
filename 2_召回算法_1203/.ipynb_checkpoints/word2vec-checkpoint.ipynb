# %% [markdown]
# 推荐系统实战-3
# =============
# 隐语义模型实战
# ------------
#
# 使用 [Text8](http://mattmahoney.net/dc/textdata) 数据集训练word2vec

# %% [markdown]
# 1.安装依赖库

# %%
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
print('check：libs well prepared')
# Out:
# check：libs well prepared

# %% [markdown]
# 2.下载数据并解压

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  #判断文件是否存在
    if not os.path.exists(filename):
        #下载
        print('download...')
        filename, _ = urlretrieve(url + filename, filename)
    #校验大小
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print('exception %s' % statinfo.st_size)
    return filename

filename = maybe_download('text8.zip', 31344016)
# filename = maybe_download('text8.zip', 28958232)
# Out:
# Found and verified text8.zip

# %%
filename
# Out:
# 'text8.zip'

# %%
#解压缩文件并将其字符分割
def read_data(filename):
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
words[1]
# Out:
# 'originated'

# %%
collections.Counter(words)
# Out:
# Counter({'atrous': 1,
#          'mathcalf': 3,
#          'irsay': 8,
#          'rostropovich': 4,
#          'tailored': 44,
#          'komputoro': 1,
#          'barbegazi': 1,
#          'versteegh': 4,
#          'losengry': 1,
#          'kal': 23,
#          'moerore': 1,
#          'geresh': 1,
#          'mooseport': 2,
#          'sidstring': 4,
#          'efforts': 1240,
#          'benzoxazinoids': 1,
#          'mohyla': 1,
#          'swofford': 1,
#          'iolanthe': 3,
#          'tapestry': 29,
#          'archaeological': 366,
#          'sightings': 91,
#          'abaq': 1,
#          'served': 1836,
#          'jordan': 874,
#          'clinger': 1,
#          'akins': 4,
#          'poslovenskee': 1,
#          'oikia': 1,
#          'sch': 115,
#          'mov': 13,
#          'vidarbha': 6,
#          'smallscale': 4,
#          'jeshrun': 1,
#          'qabbani': 6,
#          'pieterse': 1,
#          'bowlby': 1,
#          'carenet': 1,
# ...

# %% [markdown]
# 3.编码并替换低频次

# %%
vocabulary_size = 50000 #最多出现的词汇

def build_dataset(words):
    count = [['UNK', -1]]
  #每个词出现的次数（设定初始为这种形式["", num]）
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    #统计每个单词出现的此处，并且找出频此最高的返回一个TopN列表。如果指定为vocabulary_size - 1
    dictionary = dict()
   #单词到数字的映射
    for word, _ in count:
        dictionary[word] = len(dictionary)
    #dictionary每一个单词对应序列索引
    data = list()
    unk_count = 0
    for word in words:
        #对于word的每一个单词若在dictionary中，则其索引为index存入data
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0 
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
  #数字到单词的映射
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

#映射之后的训练数据
data, count, dictionary, reverse_dictionary = build_dataset(words)
#
print('Most common words (+UNK)', count[:5])
print('original data', words[:10])
print('training data', data[:10])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# original data ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# training data [5240, 3082, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# 4.生成skip-gram训练数据

# %%
def generate_batch(batch_size, num_skips, skip_window):
    #num_skips从窗口中选取多少一个input
    #skip_window窗口大小
    global data_index #data_index为来源外界的全局变量
    assert batch_size % num_skips == 0 #一次输入的数据数量除以滑动数字的余数为0
    assert num_skips <= 2 * skip_window #num_skips小于可能抽取的数字窗口*2
   # x y输入和输出向量
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # context word context#两边context 的长度两边2加中间1
    buffer = collections.deque(maxlen=span)
    #deque 是一个双端队列, 如果要经常从两端append 的数据，指定队列长度为5
    for _ in range(span):
        buffer.append(data[data_index]) #双端队列默认从左边添加，连续添加五个单词，生成一个batch值需要用到这么多数据
        # 循环使用训练数据
        data_index = (data_index + 1) % len(data)#data_index前一个数字输入完下一个数字并且当达len（data）重置
    for i in range(batch_size // num_skips):
        #一个batch中8个单词一次选取2个input
        target = skip_window  # 目标为2单词的距离
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            #对于一个skip的对应每一个单词
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
                #目标随机为0到span-1之间的任意数字（不为中心单词）
            targets_to_avoid.append(target)#对于一个batch_size // num_skips)当中对于一个单词的前后4个位置各个位置只能出现一次
            batch[i * num_skips + j] = buffer[skip_window]#一个batch输入一个单词
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])#第一个skip生成后bufferappend新的单词，
        #第一次buffer'anarchism', 'originated', 'as', 'a', 'term'
        #第二次'originated', 'as', 'a', 'term', 'of'于是buffer[skip_window]会对应到下一个单词
        data_index = (data_index + 1) % len(data)
    return batch, labels


print('data:', [reverse_dictionary[di] for di in data[:8]]) #输出data前8个索引对应单词
data_index = 0
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=2)
print('    batch:', [reverse_dictionary[bi] for bi in batch])
print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of']
#     labels: ['originated', 'term', 'of', 'originated', 'as', 'of', 'a', 'first']

# %% [markdown]
# 5.定义网络结构

# %%
batch_size = 128
embedding_size = 128 # 
skip_window = 1 # 
num_skips = 2 # 
valid_size = 16 # 
valid_window = 100 #
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 #

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # 输入数据
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # 定义变量
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
 #嵌入向量
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  #softmax权重和偏差

  #本次训练数据对应的embedding
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # batch loss直接求loss的平均值
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
  #优化loss，更新参数
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  #归一化
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  #用已有embedding计算valid的相似次
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
#验证数据集嵌入
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
#计算验证数据记得相似度
# Out:
# WARNING:tensorflow:From <ipython-input-10-edf0c5129950>:37: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# 6.运行训练流程

# %%
num_steps = 100000

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  average_loss = 0
  for step in range(num_steps+1):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    #2000次打印loss
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # 打印valid效果
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 5 #相似度最高的5个词
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Average loss at step 0: 8.315382
# Nearest to he: ate, notification, kickboxing, brythonic, wop,
# Nearest to a: ordaining, crests, coward, aedui, firefly,
# Nearest to american: preserves, summits, contravening, adamson, dispersal,
# Nearest to other: impart, wiesel, kato, ghibellines, danzig,
# Nearest to has: roskilde, evans, quantifier, scoring, analysed,
# Nearest to people: globally, gtb, conspirators, victor, usability,
# Nearest to by: trapped, correcting, agricola, sexist, lahr,
# Nearest to of: optimization, spectrometer, albers, predominant, civilization,
# Nearest to may: flocks, tincture, illusions, mortem, palettes,
# Nearest to called: worships, ad, applicant, county, attacks,
# Nearest to known: leakage, haldeman, faculty, spirit, dominic,
# Nearest to in: surfacing, nautical, goats, heading, auxiliary,
# Nearest to many: modulating, ux, gus, earthworm, faraway,
# Nearest to zero: horde, linkage, ware, scarred, resounding,
# ...

# %% [markdown]
# 7.可视化

# %%
#PCA降维可视化
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(20,20))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
